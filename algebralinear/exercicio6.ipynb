# %%
from plot_helper import *

# %% [markdown]
# ### Questão 6:
#
# Utilizando numpy e as bibliotecas gráficas do python, mostre que se fizermos uma
# transformação linear em um vetor, suas bases canônicas também sofrem transformação linear.

# %%
vetor = [(2, 2)]

origens = ([0, -1], [0, 1], [0, 0], [0, 2], [-3, 4])

plot_vector(vetor, origens)

pyplot.title('Um vetor com diferentes origens')
# Out:
# Text(0.5, 1.0, 'Um vetor com diferentes origens')
