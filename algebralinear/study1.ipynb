# %%
import numpy as np
from plot_helper import *

# %% [markdown]
# ### Base canônica:

# %%
i = np.array([1,0])
j = np.array([0,1])

vetores = [i,j]

plot_vector(vetores)

pyplot.title('Base canônica')
# Out:
# Text(0.5, 1.0, 'Base canônica')

# %%
vetores = [i,j, (4*i), (3*j), (4*i + 3*j)]

plot_vector(vetores)

pyplot.title('Vetor na Base Canônica')
# Out:
# Text(0.5, 1.0, 'Vetor na Base Canônica')
